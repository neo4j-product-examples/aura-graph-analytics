# %%
inputs = read.csv("https://raw.githubusercontent.com/corydonbaylor/supply-chain/refs/heads/main/data/inputs.csv")
providers = read.csv("https://raw.githubusercontent.com/corydonbaylor/supply-chain/refs/heads/main/data/providers.csv")
provision = read.csv("https://raw.githubusercontent.com/corydonbaylor/supply-chain/refs/heads/main/data/provision.csv")
seq = read.csv("https://raw.githubusercontent.com/corydonbaylor/supply-chain/refs/heads/main/data/sequence.csv")

# %%
install.packages("tidyverse")
library(tidyverse)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# ## Cleaning Provisions
#
# Two goals here:
#
#
# 1.   appx the market share
# 2.   just have organizations
#
#
# ### Market Share
# The end goal of this is to have a reasonable guess of the market share. We will use this as weights.
#
# There is two issues:
#
#
# 1.   Many inputs have nothing in the market share
# 2.   Some are listed as being neglible
#
# We will assume equal market shares among providers UNLESS they are marked as being neglible in the market. In which case, we will say that they have 1% share and that the others split the market equally.
#
# For example:
# Discrete GPU has AMD, Nvidia, and Jingjia Micro (which is neglible), so their weights will be:
#
#
# *   Nvidia .50
# *   AMD .50
# *   Jingjia Micro .01

# %%
# first we need to convert to decimal
provision$share_provided <- as.numeric(sub("%", "", provision$share_provided)) / 100

# %% [markdown]
# Next, we are going to make an educated guess at a market share. If its neglible we will put its share at 1% and take it out of its group

# %%
provision = provision%>%mutate(group = ifelse(negligible_market_share == "negligible", "small", provided_id))

# %% [markdown]
# Next we are going to equally divide the market share amongst the vendors based on if they provide that input

# %%
provision = provision%>%
  group_by(group)%>%
  mutate(share = ifelse(
    group == "small", .01,
    ifelse(is.na(share_provided), 1/n(), share_provided)
  )
  )%>%ungroup

# %% [markdown]
# Next, I would like to **just** consider organizations rather than countries. We first need to get a list of organizations:

# %%
orgs = providers%>%filter(provider_type == "organization")

# %% [markdown]
# Then filter them out of the provision table

# %%
org_prov = provision %>% filter(provider_id %in% orgs$provider_id)

# %%
org_prov%>%
  filter(provider_id == "P34")
# Out:
#   provider_name provider_id provided_name                          provided_id
# 1 TSMC          P34         Fabrication                            S2
# 2 TSMC          P34         Assembly, testing, and packaging (ATP) S3
# 3 TSMC          P34         Advanced photomasks                    N33
#   share_provided negligible_market_share group share
# 1 NA                                     S2    0.05555556
# 2 NA                                     S3    0.04761905
# 3 NA                                     N33   0.08333333

# %%
head(org_prov)
# Out:
#   provider_name provider_id provided_name                    provided_id
# 1 Intel         P9          Logic chip design: Advanced CPUs N1
# 2 AMD           P10         Logic chip design: Advanced CPUs N1
# 3 Nvidia        P11         Logic chip design: Discrete GPUs N2
# 4 Jingjia Micro P12         Logic chip design: Discrete GPUs N2
# 5 Loongson      P13         Logic chip design: Advanced CPUs N1
# 6 Zhaoxin       P14         Logic chip design: Advanced CPUs N1
#   share_provided negligible_market_share group share
# 1 NA                                     N1    0.50
# 2 NA                                     N1    0.50
# 3 NA                                     N2    0.50
# 4 NA             negligible              small 0.01
# 5 NA             negligible              small 0.01
# 6 NA             negligible              small 0.01

# %% [markdown]
# ## Cleaning up the Sequence Table
#
# We want to have the following graph model:
#
# `(provider) -[outputs]-> (input) -[input]-> (provider)`
#
# Lets walk through an example:
#
# `(N8: Crystal Growing Furnaces)` is an input to `[Shin-Etsu, SUMCO, or GlobalWafers]` who makes `(wafers)`
#
# We already have the outputs relationship captured in the provision table. But we need the inputs captured.

# %% [markdown]
# ### Removing type of in the sequence
#
# N20-22 are types of N19. Ideally, this subset of inputs wouldnt exist.

# %%
head(seq)
# Out:
#   input_name                          input_id goes_into_name   goes_into_id
# 1 Crystal growing furnaces            N8       Wafer            N26
# 2 Crystal machining tools             N9       Wafer            N26
# 3 EUV scanners                        N20
# 4 ArF scanners                        N21
# 5 ArF immersion scanners              N22
# 6 Advanced photolithography equipment N19      Photolithography N25
#   is_type_of_name                     is_type_of_id
# 1
# 2
# 3 Advanced photolithography equipment N19
# 4 Advanced photolithography equipment N19
# 5 Advanced photolithography equipment N19
# 6

# %%
types2
# Out:
#    input_name                                input_id goes_into_name
# 1  EUV scanners                              N20
# 2  ArF scanners                              N21
# 3  ArF immersion scanners                    N22
# 4  Electron-beam lithography tools           N29
# 5  Laser lithography tools                   N30
# 6  Plasma CVD tools                          N38
# 7  Low-pressure CVD tools                    N39
# 8  High-temperature CVD tools                N40
# 9  Atomic layer deposition tools             N41
# 10 Physical vapor deposition tools           N42
# 11 Rapid thermal processing tools            N43
# 12 Tube-based diffusion and deposition tools N44
# 13 Electrochemical coating tools             N45
# 14 Chemical vapor deposition tools           N47
# 15 Dry etching and cleaning tools            N48
# 16 Wet etching and cleaning tools            N49
# 17 Conductor etching tools                   N50
# 18 Dielectric etching tools                  N51
# 19 Film and wafer measuring tools            N65
# 20 Critical dimensions measurement tools     N66
# 21 Defect inspection tools                   N67
# 22 General-purpose microscopy tools          N68
# 23 Die attaching tools                       N73
# 24 Wire bonding tools                        N74
# 25 Advanced interconnect tools               N75
# 26 Lead frames                               N93
# 27 Bond wires                                N94
# 28 Ceramic packages                          N95
# 29 Substrates                                N96
# 30 Encapsulation resins                      N97
# 31 Die attach materials                      N98
#    is_type_of_name                            is_type_of_id goes_into_id
# 1  Advanced photolithography equipment        N19           N25
# 2  Advanced photolithography equipment        N19           N25
# 3  Advanced photolithography equipment        N19           N25
# 4  Photomask (maskless) lithography equipment N28           N33
# 5  Photomask (maskless) lithography equipment N28           N33
# 6  Chemical vapor deposition tools            N47           N35
# 7  Chemical vapor deposition tools            N47           N35
# 8  Chemical vapor deposition tools            N47           N35
# 9  Chemical vapor deposition tools            N47           N35
# 10 Deposition tools                           N36           N35
# 11 Deposition tools                           N36           N35
# 12 Deposition tools                           N36           N35
# 13 Deposition tools                           N36           N35
# 14 Deposition tools                           N36           N35
# 15 Etching and cleaning tools                 N55           N46
# 16 Etching and cleaning tools                 N55           N46
# 17 Dry etching and cleaning tools             N48           N55
# 18 Dry etching and cleaning tools             N48           N55
# 19 Wafer inspection equipment                 N61           N60
# 20 Wafer inspection equipment                 N61           N60
# 21 Wafer inspection equipment                 N61           N60
# 22 Wafer inspection equipment                 N61           N60
# 23 Bonding tools                              N72           N69
# 24 Bonding tools                              N72           N69
# 25 Bonding tools                              N72           N69
# 26 Packaging materials                        N100          N69
# 27 Packaging materials                        N100          N69
# 28 Packaging materials                        N100          N69
# 29 Packaging materials                        N100          N69
# 30 Packaging materials                        N100          N69
# 31 Packaging materials                        N100          N69

# %%
# this represents inputs that directly go into another input
seq_x = seq %>% filter(grepl("N|S", goes_into_id))

# this represents inputs that are a type of another input
types = seq %>% filter(!grepl("N|S", goes_into_id))

# we are going to make a crosswalk of those inputs
seq_x_slim = seq%>%select(input_id, goes_into_id)

# we then join types to seq df to find what the supergroup goes into
# for example, N20-22 are a type of N19 and N19 goes into N25
# therefore, N20-22 goes into N25
types2 = types%>%left_join(seq_x_slim, by = c("is_type_of_id" = "input_id"))%>%
  select(-goes_into_id.x)%>%
  rename(goes_into_id= goes_into_id.y)

head(types2)
# Out:
#   input_name                      input_id goes_into_name
# 1 EUV scanners                    N20
# 2 ArF scanners                    N21
# 3 ArF immersion scanners          N22
# 4 Electron-beam lithography tools N29
# 5 Laser lithography tools         N30
# 6 Plasma CVD tools                N38
#   is_type_of_name                            is_type_of_id goes_into_id
# 1 Advanced photolithography equipment        N19           N25
# 2 Advanced photolithography equipment        N19           N25
# 3 Advanced photolithography equipment        N19           N25
# 4 Photomask (maskless) lithography equipment N28           N33
# 5 Photomask (maskless) lithography equipment N28           N33
# 6 Chemical vapor deposition tools            N47

# %%
# only include types and not super groups like "Dry etching and cleaning tools"
# unforunately have to hard code a few things:
types2 = types2%>% mutate(goes_into_id = ifelse(is_type_of_id == "N47", "N35", goes_into_id))
types2 = types2%>% mutate(goes_into_id = ifelse(is_type_of_id == "N48", "N55", goes_into_id))

head(types2)
# Out:
#   input_name                      input_id goes_into_name
# 1 EUV scanners                    N20
# 2 ArF scanners                    N21
# 3 ArF immersion scanners          N22
# 4 Electron-beam lithography tools N29
# 5 Laser lithography tools         N30
# 6 Plasma CVD tools                N38
#   is_type_of_name                            is_type_of_id goes_into_id
# 1 Advanced photolithography equipment        N19           N25
# 2 Advanced photolithography equipment        N19           N25
# 3 Advanced photolithography equipment        N19           N25
# 4 Photomask (maskless) lithography equipment N28           N33
# 5 Photomask (maskless) lithography equipment N28           N33
# 6 Chemical vapor deposition tools            N47           N35

# %%
# now we need to combine types2 and seq_x
sequence = seq_x%>%bind_rows(types2)
# we still have the same number of rows as when we started so that is good
var = "N43"
sequence%>%
  filter(input_id == var | goes_into_id == var)
# Out:
#   input_name                     input_id goes_into_name goes_into_id
# 1 Rapid thermal processing tools N43                     N35
#   is_type_of_name  is_type_of_id
# 1 Deposition tools N36

# %% [markdown]
# ### Finding Inputs (to a Provider)
# Next we need to find out what inputs each provider needs before it can make an output.
#
# Let's walk through an example.
# - For N26 (wafers), we require N8 and N9.
# - N8 has a list of suppliers in the org_prov that we could use
# - that list is all the potential suppliers for N8

# %%
# next we need to know what suppliers each input relies on
provision_slim = org_prov%>%select(provider_id, provided_id)
head(provision_slim)
# Out:
#   provider_id provided_id
# 1 P9          N1
# 2 P10         N1
# 3 P11         N2
# 4 P12         N2
# 5 P13         N1
# 6 P14         N1

# %%
provision_slim%>%filter(provided_id == "N33")
# Out:
#    provider_id provided_id
# 1  P238        N33
# 2  P239        N33
# 3  P240        N33
# 4  P241        N33
# 5  P242        N33
# 6  P9          N33
# 7  P35         N33
# 8  P34         N33
# 9  P36         N33
# 10 P37         N33
# 11 P205        N33

# %%
sequence%>%
  filter(goes_into_id == "N97")
# Out:
#      input_name input_id goes_into_name goes_into_id is_type_of_name
#      is_type_of_id

# %%
a = provision_slim%>%
  filter(grepl("S", provided_id))%>%
  left_join(inputs, by = c("provided_id" = "stage_id"))%>%
  select(provider_id, input_id)%>%
  rename(provided_id = input_id)

b = provision_slim%>%
  filter(grepl("N", provided_id))

final_provision = rbind(a,b)
# Out:
# Warning message in left_join(., inputs, by = c(provided_id = "stage_id")):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 1 of `x` matches multiple rows in `y`.
# ℹ Row 15 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”

# %%
inputs_to_providers = final_provision %>%
  left_join(sequence, by = c("provided_id" = "goes_into_id"))%>%
  select(provider_id, provided_id, input_id)

nrow(inputs_to_providers)

inputs_to_providers%>%
  filter(provided_id == "N78")
#write.csv(inputs_to_providers, "inputs_to_providers.csv", row.names=F)
# Out:
# Warning message in left_join(., sequence, by = c(provided_id = "goes_into_id")):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 1 of `x` matches multiple rows in `y`.
# ℹ Row 3 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# [1] 1427
#    provider_id provided_id input_id
# 1  P49         N78         N69
# 2  P49         N78         N80
# 3  P49         N78         N81
# 4  P49         N78         N82
# 5  P49         N78         N83
# 6  P50         N78         N69
# 7  P50         N78         N80
# 8  P50         N78         N81
# 9  P50         N78         N82
# 10 P50         N78         N83
# 11 P57         N78         N69
# 12 P57         N78         N80
# 13 P57         N78         N81
# 14 P57         N78         N82
# 15 P57         N78         N83
# 16 P52         N78         N69
# 17 P52         N78         N80
# 18 P52         N78         N81
# 19 P52         N78         N82
# 20 P52         N78         N83
# 21 P53         N78         N69
# 22 P53         N78         N80
# 23 P53         N78         N81
# 24 P53         N78         N82
# 25 P53         N78         N83
# 26 P54         N78         N69
# 27 P54         N78         N80
# 28 P54         N78         N81
# 29 P54         N78         N82
# 30 P54         N78         N83
# ⋮  ⋮           ⋮           ⋮
# 36 P56         N78         N69
# 37 P56         N78         N80
# 38 P56         N78         N81
# 39 P56         N78         N82
# 40 P56         N78         N83
# 41 P57         N78         N69
# 42 P57         N78         N80
# 43 P57         N78         N81
# 44 P57         N78         N82
# 45 P57         N78         N83
# 46 P9          N78         N69
# 47 P9          N78         N80
# 48 P9          N78         N81
# 49 P9          N78         N82
# 50 P9          N78         N83
# 51 P35         N78         N69
# 52 P35         N78         N80
# 53 P35         N78         N81
# 54 P35         N78         N82
# 55 P35         N78         N83
# 56 P34         N78         N69
# 57 P34         N78         N80
# 58 P34         N78         N81
# 59 P34         N78         N82
# 60 P34         N78         N83
# 61 P48         N78         N69
# 62 P48         N78         N80
# 63 P48         N78         N81
# 64 P48         N78         N82
# 65 P48         N78         N83

# %%
write.csv(inputs_to_providers, "inputs_to_providers.csv", row.names=F)

# %%
write.csv(final_provision, "outputs.csv", row.names=F)

# %%
write.csv(sequence, "sequence_final.csv", row.names=F)

# %%
write.csv(orgs, "organizatons.csv", row.names=F)
